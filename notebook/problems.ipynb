# %% [markdown]
# # Visualization Exercises with Matplotlib and Seaborn
#
# Data visualization is one of the most important tools in data analysis and data science. It not only allows us to explore and better understand the data, but it also helps us communicate findings effectively. Through graphs, we can detect patterns, relationships, and anomalies that would be difficult to identify with just numbers or tables.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exercise 1 - Simple Line Plot
#
# Suppose that in your office, it takes you 10 seconds to walk 25 meters leisurely to the coffee machine. If we want to express this situation as a linear function of distance with respect to time, we use the formula:
#
# $
# \text{distance} = \text{speed} \times \text{time}
# $
#
# Since the speed is constant, it represents the slope of the function and can be interpreted as the first derivative of distance with respect to time. That is, it indicates how fast the distance changes as time passes.
#
# - **Calculate the constant speed at which you walk:** We know that you walked 25 meters in 10 seconds. What is the speed (in meters/second)?
# - **Construct the linear function that describes how distance changes with time:** Use the formula `distance = speed × time` to calculate the distance traveled each second from 0 to 10.
# - **Use Matplotlib to plot how distance changes with time:** Add labels to the axes and a title to the plot.

# %%
x = np.arange(0, 11) # array with values from 0 to 10

# Calculate the constant speed
speed = 25 / 10  # 25 meters in 10 seconds

# Construct the linear function: distance = speed × time
y = speed * x

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y, linewidth=2, marker='o')
plt.xlabel('Time (seconds)', fontsize=12)
plt.ylabel('Distance (meters)', fontsize=12)
plt.title('Distance vs Time - Walking to the Coffee Machine', fontsize=14)
plt.grid(True, alpha=0.3)
plt.show()

print(f"Speed: {speed} m/s")
# Out:
# Speed: 2.5 m/s

# %% [markdown]
# ### What do you think would happen to the graph if you walked faster or slower? How would the slope change? Try changing the speed to 3 m/s and plot again.

# %%
x = np.arange(0, 11) # array with values from 0 to 10
velocity = 3
y = velocity * x

# Plot the data with faster speed
plt.figure(figsize=(10, 6))
plt.plot(x, y, linewidth=2, marker='o', color='red', label='3 m/s (faster)')
plt.xlabel('Time (seconds)', fontsize=12)
plt.ylabel('Distance (meters)', fontsize=12)
plt.title('Distance vs Time - Walking at 3 m/s (Faster Pace)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

print(f"Faster speed: {velocity} m/s")
print(f"At 10 seconds, you would cover {velocity * 10} meters")
# Out:
# Faster speed: 3 m/s
# At 10 seconds, you would cover 30 meters

# %% [markdown]
# ## Exercise 2 - Visually Representing Categorical Data
#
# Imagine you are analyzing how many students are enrolled in different majors within a university. This data, which represents **categories** (the majors), is ideal for visualization using a **bar chart**.
#
# Below is a small dataset with the number of students per major.

# %%
df_carreras = pd.DataFrame({
    'Major': ['Engineering', 'Medicine', 'Law', 'Psychology'],
    'Students': [120, 80, 60, 100]
})

df_carreras # Show the DataFrame
# Out:
#          Major  Students
# 0  Engineering       120
# 1     Medicine        80
# 2          Law        60
# 3   Psychology       100

# %% [markdown]
# 1. Graphically represent how many students are in each major using a vertical bar chart with Matplotlib.
# 2. Label the axes correctly and add a descriptive title.
# 3. Use a color that helps highlight the differences between categories.

# %%
# Create a vertical bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_carreras['Major'], df_carreras['Students'], color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A'], edgecolor='black', linewidth=1.5)
plt.xlabel('Major', fontsize=12, fontweight='bold')
plt.ylabel('Number of Students', fontsize=12, fontweight='bold')
plt.title('Student Enrollment by Major', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3, linestyle='--')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What would happen if you use a **horizontal** bar chart? Is it more readable? Try to do it

# %%
# Create a horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(df_carreras['Major'], df_carreras['Students'], color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A'], edgecolor='black', linewidth=1.5)
plt.xlabel('Number of Students', fontsize=12, fontweight='bold')
plt.ylabel('Major', fontsize=12, fontweight='bold')
plt.title('Student Enrollment by Major (Horizontal View)', fontsize=14, fontweight='bold')
plt.grid(axis='x', alpha=0.3, linestyle='--')
plt.tight_layout()
plt.show()

print("The horizontal bar chart is more readable because:")
print("- Major names are easier to read horizontally")
print("- No need to rotate text on the x-axis")
print("- Better for comparing values when category names are long")
# Out:
# The horizontal bar chart is more readable because:
# - Major names are easier to read horizontally
# - No need to rotate text on the x-axis
# - Better for comparing values when category names are long

# %% [markdown]
# ## Exercise 3: Visualizing Proportions with a Pie Chart
#
# Suppose you want to understand how students are distributed among different majors at a university. Although you have already represented this data with a bar chart, now you want to see **what percentage of the total each major represents**.
#
# A very common way to represent proportions is by using a **pie chart**, as it provides a quick and intuitive view of how the whole is divided.
#
# - Represent the data from `df_carreras` as a pie chart.
# - Show the **percentage** that each major represents of the total.
# - Add a **descriptive title** that explains what is being visualized.

# %%
df_carreras # Show the DataFrame

# Create a pie chart showing proportions
plt.figure(figsize=(10, 8))
colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A']
explode = (0.05, 0.05, 0.05, 0.05)  # Separate all slices slightly

plt.pie(df_carreras['Students'], 
        labels=df_carreras['Major'],
        autopct='%1.1f%%',  # Show percentages
        colors=colors,
        explode=explode,
        startangle=90,
        textprops={'fontsize': 11, 'fontweight': 'bold'})

plt.title('Distribution of Students by Major', fontsize=14, fontweight='bold', pad=20)
plt.tight_layout()
plt.show()

# Print summary statistics
print("Student Distribution Summary:")
print("-" * 40)
for idx, row in df_carreras.iterrows():
    percentage = (row['Students'] / df_carreras['Students'].sum()) * 100
    print(f"{row['Major']}: {row['Students']} students ({percentage:.1f}%)")
# Out:
# Student Distribution Summary:
# ----------------------------------------
# Engineering: 120 students (33.3%)
# Medicine: 80 students (22.2%)
# Law: 60 students (16.7%)
# Psychology: 100 students (27.8%)

# %% [markdown]
# ## Exercise 4 - Exploring the Relationship Between Two Numerical Variables by Creating a Scatter Plot with Seaborn
#
# Imagine you are analyzing the characteristics of different flower species. Each flower has several measurements:
#
# - Sepal length
# - Sepal width
# - Petal length
# - Petal width
# - Species it belongs to
#
# An excellent way to **visualize the relationship between two numerical variables** is through a **scatter plot**.
#
# In this case, we will explore if there is a relationship between the `sepal length` and `sepal width`, and if this varies according to the flower species.

# %%
df_iris = pd.DataFrame({ # DataFrame with random data
    'sepal_length': np.random.normal(5.8, 0.4, 150),
    'sepal_width': np.random.normal(3.0, 0.3, 150),
    'petal_length': np.random.normal(3.7, 1.5, 150),
    'petal_width': np.random.normal(1.2, 0.8, 150),
    'species': np.random.choice(['setosa', 'versicolor', 'virginica'], 150)
})

df_iris # Show DataFrame
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0        5.856043     2.840439      4.790144     2.102044   virginica
# 1        5.930182     2.714021     -0.025970     0.846322  versicolor
# 2        5.208412     3.252672      3.733924     0.902564  versicolor
# 3        5.191426     2.929856      3.991029     0.933466      setosa
# 4        5.937009     3.476322      2.879142     2.257227   virginica
# ..            ...          ...           ...          ...         ...
# 145      5.102929     2.843759      3.850000     1.684594  versicolor
# 146      5.830197     3.078624      5.873156     0.754004      setosa
# 147      5.618715     2.734158      3.945124     1.366651   virginica
# 148      5.807066     3.085306      3.444987     1.409585   virginica
# 149      6.771756     2.920299      1.409081    -0.273532  versicolor
#
# [150 rows x 5 columns]

# %% [markdown]
# 1. Create a scatter plot with `sepal_length` on the X-axis and `sepal_width` on the Y-axis.
# 2. Use the `hue` argument to differentiate the flower species.
# 3. Add a descriptive title.
# 4. Adjust the size of the points or the color palette to make the plot clearer. **(Optional)**

# %%
# Create a scatter plot with Seaborn
plt.figure(figsize=(8,6))
sns.scatterplot(data=df_iris, x='sepal_length', y='sepal_width', hue='species', palette='Set2')
plt.title("Relationship between sepal length and width by species")
plt.xlabel("Sepal length (cm)")
plt.ylabel("Sepal width (cm)")
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercise 5 - Visualizing Distributions with Histograms
#
# In many cases, we are not only interested in the value of a variable but also in **how those values are distributed**.
#
# Histograms are a very useful visual tool to:
#
# - See if the data is **centered** or dispersed.
# - Detect **asymmetries** (e.g., if there are more low or high values).
# - Identify possible **outliers**.
# - Observe the **overall shape** of the distribution (normal, skewed, bimodal, etc.).
#
# Let's explore how the **petal length** (`petal_length`) is distributed in a flower dataset.

# %%
df_iris.head() # Show DataFrame
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0      6.694529     3.432846      4.764792     1.559191   virginica
# 1      5.631971     3.145175      4.667720     2.089405   virginica
# 2      6.290313     3.235032      4.318001     0.417130      setosa
# 3      5.802761     2.979604      5.665831     0.751771   virginica
# 4      5.686679     3.282533      3.807101     0.185974  versicolor

# %% [markdown]
# 1. Create a **histogram with `Seaborn`** to visualize the distribution of petal length (`petal_length`).
# 2. Adjust the number of *bins* to have more or less detail.
# 3. Add a title, labels, and a clear visual style.

# %%
# Create a histogram for petal length distribution
plt.figure(figsize=(12, 6))
sns.histplot(data=df_iris, 
             x='petal_length', 
             bins=20,  # Adjust number of bins
             kde=True,  # Add kernel density estimate
             color='skyblue',
             edgecolor='black',
             linewidth=1.2)

plt.xlabel('Petal Length (cm)', fontsize=12, fontweight='bold')
plt.ylabel('Frequency', fontsize=12, fontweight='bold')
plt.title('Distribution of Petal Length', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3, axis='y', linestyle='--')
plt.tight_layout()
plt.show()

print("Petal Length Distribution Statistics:")
print("-" * 50)
print(f"Mean: {df_iris['petal_length'].mean():.2f} cm")
print(f"Median: {df_iris['petal_length'].median():.2f} cm")
print(f"Std Dev: {df_iris['petal_length'].std():.2f} cm")
print(f"Min: {df_iris['petal_length'].min():.2f} cm")
print(f"Max: {df_iris['petal_length'].max():.2f} cm")
# Out:
# Petal Length Distribution Statistics:
# --------------------------------------------------
# Mean: 3.68 cm
# Median: 3.72 cm
# Std Dev: 1.67 cm
# Min: -0.81 cm
# Max: 7.60 cm

# %% [markdown]
# ## Comparison by Species (Multiple Distributions)
#
# Now, compare the distribution of petal length for each flower species using `Seaborn` and the `hue` argument.
#
# This will allow you to analyze if there are **significant differences** between the groups.

# %%
# Compare petal length distribution by species
plt.figure(figsize=(12, 6))
sns.histplot(data=df_iris, 
             x='petal_length', 
             hue='species',  # Differentiate by species
             bins=25,
             kde=True,
             palette='Set2',
             edgecolor='black',
             linewidth=1.2,
             stat='density',  # Normalize for comparison
             common_norm=False)

plt.xlabel('Petal Length (cm)', fontsize=12, fontweight='bold')
plt.ylabel('Density', fontsize=12, fontweight='bold')
plt.title('Petal Length Distribution Comparison by Species', fontsize=14, fontweight='bold')
plt.legend(title='Species', fontsize=11, title_fontsize=12)
plt.grid(True, alpha=0.3, axis='y', linestyle='--')
plt.tight_layout()
plt.show()

print("\nPetal Length Statistics by Species:")
print("-" * 50)
for sp in df_iris['species'].unique():
    species_data = df_iris[df_iris['species'] == sp]['petal_length']
    print(f"\n{sp.upper()}:")
    print(f"  Mean: {species_data.mean():.2f} cm")
    print(f"  Median: {species_data.median():.2f} cm")
    print(f"  Std Dev: {species_data.std():.2f} cm")
    print(f"  Count: {len(species_data)}")
# Out:
# /tmp/ipykernel_23113/1054450540.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Species', fontsize=11, title_fontsize=12)
# Petal Length Statistics by Species:
# --------------------------------------------------
#
# VIRGINICA:
#   Mean: 3.71 cm
#   Median: 3.92 cm
#   Std Dev: 1.58 cm
#   Count: 49
#
# SETOSA:
#   Mean: 3.77 cm
#   Median: 3.75 cm
#   Std Dev: 1.79 cm
#   Count: 52
#
# VERSICOLOR:
#   Mean: 3.55 cm
#   Median: 3.29 cm
#   Std Dev: 1.63 cm
#   Count: 49

# %% [markdown]
# ## Exercise 6 - Visualizing Relationships with Heatmaps
#
# In data science, it is important to understand how variables relate to each other. A visual way to do this is by using heatmaps, especially on correlation matrices.
#
# In this exercise, we will visualize how the numerical variables in the `df_iris` dataset are related.
#
# 1. Create a heatmap that shows the correlation between the numerical variables in the `df_iris` DataFrame. First, you need to calculate the correlation matrix using `.corr()`.
# 2. Use the **seaborn** library to plot the heatmap.
# 3. Enable the visualization of the values within the graph `(annot=True)`.

# %%
df_iris

# Calculate correlation matrix
correlation_matrix = df_iris.corr(numeric_only=True)

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix,
            annot=True,  # Show values in cells
            fmt='.2f',  # Format to 2 decimal places
            cmap='coolwarm',  # Color palette
            center=0,  # Center the colormap at 0
            square=True,  # Make cells square
            linewidths=1.5,  # Add gridlines
            cbar_kws={'label': 'Correlation Coefficient'},
            vmin=-1, vmax=1)  # Scale from -1 to 1

plt.title('Correlation Matrix - Iris Dataset', fontsize=14, fontweight='bold', pad=20)
plt.xlabel('')
plt.ylabel('')
plt.tight_layout()
plt.show()

print("Correlation Matrix Summary:")
print("-" * 50)
print("\nCorrelation Values:")
print(correlation_matrix)
print("\nInterpretation Guide:")
print("- 1.0 = Perfect positive correlation")
print("- 0.0 = No correlation")
print("- -1.0 = Perfect negative correlation")
print("\nStrong Correlations (|r| > 0.7):")
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        corr_value = correlation_matrix.iloc[i, j]
        if abs(corr_value) > 0.7:
            print(f"{correlation_matrix.columns[i]} <-> {correlation_matrix.columns[j]}: {corr_value:.3f}")
# Out:
# Correlation Matrix Summary:
# --------------------------------------------------
#
# Correlation Values:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000     0.150727     -0.126277     0.102225
# sepal_width       0.150727     1.000000     -0.105168     0.032954
# petal_length     -0.126277    -0.105168      1.000000    -0.022415
# petal_width       0.102225     0.032954     -0.022415     1.000000
#
# Interpretation Guide:
# - 1.0 = Perfect positive correlation
# - 0.0 = No correlation
# - -1.0 = Perfect negative correlation
#
# Strong Correlations (|r| > 0.7):

# %% [markdown]
# ## Exercise 7 - Visualizing Distribution by Categories with Boxplot
#
# The boxplot allows us to compare how a numerical variable is distributed across different categories.
#
# We will compare the distribution of petal length (`petal_length`) among the different flower species in the `df_iris` dataset. The goal is to create a boxplot that compares the petal length (`petal_length`) across the different species (`species`).
#
# 1. Use `seaborn.boxplot()` specifying the `x` axis with the species and the `y` axis with the petal length.
# 2. It is recommended to use `plt.figure()` to adjust the size of the plot if necessary.

# %%
# Create a boxplot comparing petal length across species
plt.figure(figsize=(12, 7))
sns.boxplot(data=df_iris,
            x='species',
            y='petal_length',
            hue='species',
            palette='Set2',
            linewidth=1.5,
            legend=False)

# Add individual data points
sns.stripplot(data=df_iris,
              x='species',
              y='petal_length',
              color='black',
              alpha=0.4,
              size=6,
              jitter=True)

plt.xlabel('Species', fontsize=12, fontweight='bold')
plt.ylabel('Petal Length (cm)', fontsize=12, fontweight='bold')
plt.title('Petal Length Distribution Across Flower Species', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3, axis='y', linestyle='--')
plt.tight_layout()
plt.show()

print("Boxplot Summary - Petal Length by Species:")
print("-" * 50)
print("\nBox plot components:")
print("- Box: Shows the interquartile range (IQR)")
print("- Line in box: Shows the median")
print("- Whiskers: Show the range of data")
print("- Points: Individual data observations")
print("\nStatistics by Species:")
for sp in sorted(df_iris['species'].unique()):
    species_data = df_iris[df_iris['species'] == sp]['petal_length']
    print(f"\n{sp.upper()}:")
    print(f"  Q1 (25%): {species_data.quantile(0.25):.2f} cm")
    print(f"  Median (50%): {species_data.quantile(0.50):.2f} cm")
    print(f"  Q3 (75%): {species_data.quantile(0.75):.2f} cm")
    print(f"  IQR: {species_data.quantile(0.75) - species_data.quantile(0.25):.2f} cm")
# Out:
# Boxplot Summary - Petal Length by Species:
# --------------------------------------------------
#
# Box plot components:
# - Box: Shows the interquartile range (IQR)
# - Line in box: Shows the median
# - Whiskers: Show the range of data
# - Points: Individual data observations
#
# Statistics by Species:
#
# SETOSA:
#   Q1 (25%): 2.71 cm
#   Median (50%): 3.75 cm
#   Q3 (75%): 5.13 cm
#   IQR: 2.41 cm
#
# VERSICOLOR:
#   Q1 (25%): 2.49 cm
#   Median (50%): 3.29 cm
#   Q3 (75%): 4.74 cm
#   IQR: 2.26 cm
#
# VIRGINICA:
#   Q1 (25%): 2.77 cm
#   Median (50%): 3.92 cm
#   Q3 (75%): 4.76 cm
#   IQR: 2.00 cm
